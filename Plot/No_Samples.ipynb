# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ID = ['UEB-0205', 'UEB-0208', 'UEB-0209', 'UEB-0210', 'UEB-0211', 'UEB-0213', 'UEB-0214', 
     'UEB-0215', 'UEB-0216', 'UEB-0217', 'UEB-0218', 'UEB-0219', 'UEB-0220', 'UEB-0221', 
     'UEB-0222', 'UEB-0223', 'UEB-0224', 'UEB-0226', 'UEB-0227', 'UEB-0228', 'UEB-0212', 
      'UEB-0225', 'UEB-0229', 'UEB-0230', 'UEB-0231', 'UEB-0232', 'UEB-0233', 'UEB-0234', 
      'UEB-0235', 'UEB-0236', 'UEB-0237', 'UEB-0238', 'UEB-0239', 'UEB-0240', 'UEB-0241',
      'UEB-0242', 'UEB-0243', 'UEB-0244']
freq_cfDNA = [1] * 20 + [0] * 18
freq_tumor = [1] * 38

# Ajustar el tamaño de la letra
plt.rcParams['font.size'] = 14
plt.figure(figsize=(15, 3.3)) 

plt.bar(ID, freq_tumor, label='Tumor', color = '#FF6363')
plt.bar(ID, freq_cfDNA, bottom=freq_cfDNA, label='cfDNA', color = '#636FFF')


plt.xticks(rotation=90)
plt.yticks([0, 1, 2])
plt.ylabel('No. of samples'); plt.xlabel('ID')
# Añadir leyenda
plt.legend()

# Ajustar el diseño
plt.tight_layout()
# Ajustar los límites del eje x
plt.xlim(-0.5, len(ID)-0.5)

plt.savefig('/home/fer/NoSamples.pdf')
