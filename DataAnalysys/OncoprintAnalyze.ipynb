# %%
import pandas as pd

# %%
df = pd.read_csv('/home/fer/Documents/cfDNA/OncoprintAll_mergeDirectionality/Base_v5 OnlyCNV.csv')
df
# Out:
#    Unnamed: 0            Unnamed: 1              Unnamed: 2       Unnamed: 3  \
# 0         NaN                   NaN                     NaN              NaN
# 1         NaN                   NaN                     NaN              NaN
# 2         NaN                   NaN                     NaN              NaN
# 3         NaN                   NaN                     NaN              NaN
# 4         NaN                   NaN                     NaN              NaN
# 5         NaN                   NaN                     NaN              NaN
# 6         NaN                   NaN                     NaN              NaN
# 7         NaN                   NaN                     NaN              NaN
# 8         NaN                   NaN                     NaN              NaN
# 9         NaN                   NaN                     NaN              NaN
# 10        NaN                   NaN                     NaN              NaN
# ...

# %%
x = pd.DataFrame(df['Unnamed: 1'].value_counts())
x['percent'] = (x['Unnamed: 1'] / x['Unnamed: 1'].sum()) * 100
x
# Out:
#                       Unnamed: 1    percent
# Transcription factor           8  22.222222
# Cell cycle                     8  22.222222
# Chromatin                      6  16.666667
# DNA repair                     4  11.111111
# PI3K/mTOR                      3   8.333333
# RAS/MAPK                       2   5.555556
# Function                       1   2.777778
# Exoribonuclease                1   2.777778
# Oxidative stress               1   2.777778
# Cell adhesion                  1   2.777778
# Wnt                            1   2.777778

# %%
x = pd.DataFrame(df['Unnamed: 2'].value_counts())
x
# Out:
#                         Unnamed: 2
# Uncertain significance          21
# Likely pathogenic               12
# Pathogenic                       2
# Status                           1

# %%
x = pd.DataFrame(df['Unnamed: 0'].value_counts())
x
# Out:
#       Unnamed: 0
# CNV           35
# Type           1
