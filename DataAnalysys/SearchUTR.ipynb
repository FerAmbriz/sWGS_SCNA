# %%
import pandas as pd

# %%
df = pd.read_csv('/home/fer/Documents/cfDNA/Tumor/Data/Colombia_Merge.wNULL.txt', sep ='\t')
df
# Out:
# /tmp/ipykernel_55658/3235158661.py:1: DtypeWarning: Columns (33,34,35,36,37,38,42,46,49,52,55,58,61,64,67,72,75,78,86,87,107,108,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/fer/Documents/cfDNA/Tumor/Data/Colombia_Merge.wNULL.txt', sep ='\t')
#          Sample             Chr   Start     End Ref Alt Func.refGene  \
# 0        UEB_10            chr1  527018  527018   G   A   intergenic
# 1        UEB_10            chr1  527030  527030   C   T   intergenic
# 2        UEB_10            chr1  863641  863641   G   A     intronic
# 3        UEB_10            chr1  863644  863644   T   C     intronic
# 4        UEB_10            chr1  863689  863689   A   G     intronic
# ...         ...             ...     ...     ...  ..  ..          ...
# 2136064  UEB_86  chrUn_gl000226   14292   14292   G   C   intergenic
# 2136065  UEB_86  chrUn_gl000226   14300   14300   T   G   intergenic
# ...

# %%
#df[(df['Func.refGene']=='Nonsynonymous')]
df['Func.refGene'].value_counts()
# Out:
# intergenic               1091189
# intronic                  825814
# ncRNA_intronic            121299
# UTR3                       26161
# exonic                     21152
# downstream                 17105
# upstream                   16708
# ncRNA_exonic                9046
# UTR5                        6188
# upstream;downstream         1026
# splicing                     299
# ncRNA_exonic;splicing         34
# ncRNA_splicing                30
# exonic;splicing               11
# UTR5;UTR3                      7
# Name: Func.refGene, dtype: int64

# %%
df['ExonicFunc.refGene'].value_counts()
# Out:
# synonymous SNV                8367
# nonsynonymous SNV             8046
# nonframeshift deletion        2264
# nonframeshift insertion        677
# frameshift deletion            586
# stopgain                       416
# frameshift insertion           325
# unknown                        252
# nonframeshift substitution     214
# stoploss                        10
# startloss                        6
# Name: ExonicFunc.refGene, dtype: int64

# %%
df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR5')]
# Out:
#          Sample    Chr     Start       End Ref  Alt Func.refGene Gene.refGene  \
# 231636   UEB_23  chr18  48556610  48556610   C    T         UTR5        SMAD4
# 231637   UEB_23  chr18  48556626  48556626   C    G         UTR5        SMAD4
# 471069   UEB_27  chr18  48556671  48556671   A    G         UTR5        SMAD4
# 1971456  UEB_83  chr18  48556728  48556728   -  CTG         UTR5        SMAD4
# 2030130  UEB_84  chr18  48556688  48556688   T    C         UTR5        SMAD4
#
#                       GeneDetail.refGene ExonicFunc.refGene  ... Otherinfo.3  \
# 231636             NM_005359:c.-16807C>T                NaN  ...       chr18
# 231637             NM_005359:c.-16791C>G                NaN  ...       chr18
# 471069             NM_005359:c.-16746A>G                NaN  ...       chr18
# 1971456  NM_005359:c.-16689_-16688insCTG                NaN  ...       chr18
# 2030130            NM_005359:c.-16729T>C                NaN  ...       chr18
#
# ...

# %%
df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR3')]
# Out:
#          Sample    Chr     Start       End    Ref Alt Func.refGene  \
# 36261    UEB_10  chr18  48606336  48606336      T   -         UTR3
# 36262    UEB_10  chr18  48609103  48609103      T   -         UTR3
# 36263    UEB_10  chr18  48609832  48609832      T   -         UTR3
# 36264    UEB_10  chr18  48609968  48609968      A   G         UTR3
# 36265    UEB_10  chr18  48610371  48610372     CA   -         UTR3
# ...         ...    ...       ...       ...    ...  ..          ...
# 2077183   UEB_8  chr18  48610698  48610702  AAGAA   -         UTR3
# 2077184   UEB_8  chr18  48610831  48610831      A   C         UTR3
# 2129545  UEB_86  chr18  48609103  48609103      T   -         UTR3
# 2129546  UEB_86  chr18  48609832  48609832      T   -         UTR3
# 2129547  UEB_86  chr18  48610382  48610382      G   A         UTR3
#
#         Gene.refGene               GeneDetail.refGene ExonicFunc.refGene  ...  \
# 36261          SMAD4            NM_005359:c.*1499delT                NaN  ...
# ...

# %% [markdown]
# # Search frameshift

# %%
new_var1 = df[(df['Sample'] == 'UEB_39') & (df['Gene.refGene']=='BRCA2')&(df['ExonicFunc.refGene']=='frameshift insertion')]
new_var1
# Out:
#          Sample    Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 1079555  UEB_39  chr13  32914515  32914515   -   G       exonic        BRCA2
#
#         GeneDetail.refGene    ExonicFunc.refGene  ... Otherinfo.3  \
# 1079555                NaN  frameshift insertion  ...       chr13
#
#          Otherinfo.4  Otherinfo.5  Otherinfo.6  Otherinfo.7  Otherinfo.8  \
# 1079555     32914515          NaN            A           AG          NaN
#
#          Otherinfo.9                                       Otherinfo.10  \
# 1079555         PASS  AS_FilterStatus=SITE;AS_SB_TABLE=18,19|22,22;D...
#
#                      Otherinfo.11                                Otherinfo.12
# 1079555  GT:AD:AF:DP:F1R2:F2R1:SB  0/1:37,44:0.540:81:21,27:16,17:18,19,22,22
#
# [1 rows x 140 columns]

# %% [markdown]
# # Search UTR

# %%
## SMAD4
UEB_0214_SMAD4 = df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_44')]
UEB_0237_SMAD4 = df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_49')]
UEB_0234_SMAD4 = df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_12')]
UEB_0235_SMAD4 = df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_45')]
UEB_0215_SMAD4 = df[(df['Gene.refGene']=='SMAD4')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_47')]
UEB_0235_SMAD4
# Out:
#          Sample    Chr     Start       End Ref     Alt Func.refGene  \
# 1261504  UEB_45  chr18  48606178  48606178   -       T         UTR3
# 1261505  UEB_45  chr18  48606336  48606337  TT       -         UTR3
# 1261506  UEB_45  chr18  48606940  48606940   C       A         UTR3
# 1261507  UEB_45  chr18  48609103  48609104  TT       -         UTR3
# 1261508  UEB_45  chr18  48609832  48609832   T       -         UTR3
# 1261509  UEB_45  chr18  48610380  48610380   -  CACACA         UTR3
# 1261510  UEB_45  chr18  48610382  48610382   G       A         UTR3
#
#         Gene.refGene                GeneDetail.refGene ExonicFunc.refGene  \
# 1261504        SMAD4       NM_005359:c.*1341_*1342insT                NaN
# 1261505        SMAD4      NM_005359:c.*1499_*1500delTT                NaN
# 1261506        SMAD4              NM_005359:c.*2103C>A                NaN
# 1261507        SMAD4      NM_005359:c.*4266_*4267delTT                NaN
# ...

# %%
UEB_0241_STK11 = df[(df['Gene.refGene']=='STK11')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_14')]
UEB_0214_STK11 = df[(df['Gene.refGene']=='STK11')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_44')]
UEB_0237_STK11 = df[(df['Gene.refGene']=='STK11')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_49')]
UEB_0240_STK11 = df[(df['Gene.refGene']=='STK11')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_8')]
UEB_0240_STK11
# Out:
#         Sample    Chr    Start      End Ref Alt Func.refGene Gene.refGene  \
# 2078671  UEB_8  chr19  1228059  1228059   T   -         UTR3        STK11
# 2078672  UEB_8  chr19  1228191  1228191   T   C         UTR3        STK11
#
#            GeneDetail.refGene ExonicFunc.refGene  ... Otherinfo.3  \
# 2078671  NM_000455:c.*484delT                NaN  ...       chr19
# 2078672   NM_000455:c.*616T>C                NaN  ...       chr19
#
#          Otherinfo.4  Otherinfo.5  Otherinfo.6  Otherinfo.7  Otherinfo.8  \
# 2078671      1228058          NaN           CT            C          NaN
# 2078672      1228191          NaN            T            C          NaN
#
#                                     Otherinfo.9  \
# 2078671  multiallelic;panel_of_normals;slippage
# 2078672                        panel_of_normals
#
#                                               Otherinfo.10  \
# 2078671  AS_FilterStatus=weak_evidence|SITE;AS_SB_TABLE...
# ...

# %%
UEB_0234_RUNX1 = df[(df['Gene.refGene']=='RUNX1')&(df['Func.refGene']=='UTR3')&(df['Sample']=='UEB_14')]
UEB_0234_RUNX1
# Out:
#         Sample    Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 123629  UEB_14  chr21  36161662  36161662   G   C         UTR3        RUNX1
# 123630  UEB_14  chr21  36161882  36161883  CA   -         UTR3        RUNX1
# 123631  UEB_14  chr21  36161902  36161903  CA   -         UTR3        RUNX1
# 123632  UEB_14  chr21  36164405  36164405   G   T         UTR3        RUNX1
# 123635  UEB_14  chr21  36193871  36193871   T   C         UTR3        RUNX1
#
#                                        GeneDetail.refGene ExonicFunc.refGene  \
# 123629       NM_001754:c.*2770C>G;NM_001001890:c.*2770C>G                NaN
# 123630  NM_001754:c.*2550_*2549delTG;NM_001001890:c.*2...                NaN
# 123631  NM_001754:c.*2530_*2529delTG;NM_001001890:c.*2...                NaN
# 123632           NM_001754:c.*27C>A;NM_001001890:c.*27C>A                NaN
# 123635                              NM_001122607:c.*94A>G                NaN
#
# ...

# %%
df_final = pd.concat([new_var1, UEB_0215_SMAD4,UEB_0214_SMAD4, UEB_0237_SMAD4, UEB_0234_SMAD4, 
                      UEB_0235_SMAD4, UEB_0241_STK11, UEB_0214_STK11, UEB_0237_STK11, 
                      UEB_0240_STK11,UEB_0234_RUNX1])
df_final
# Out:
#          Sample    Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 1079555  UEB_39  chr13  32914515  32914515   -   G       exonic        BRCA2
# 1308994  UEB_47  chr18  48605008  48605008   T   -         UTR3        SMAD4
# 1308995  UEB_47  chr18  48606178  48606178   -   T         UTR3        SMAD4
# 1308996  UEB_47  chr18  48606336  48606337  TT   -         UTR3        SMAD4
# 1308997  UEB_47  chr18  48609103  48609103   T   -         UTR3        SMAD4
# ...         ...    ...       ...       ...  ..  ..          ...          ...
# 123629   UEB_14  chr21  36161662  36161662   G   C         UTR3        RUNX1
# 123630   UEB_14  chr21  36161882  36161883  CA   -         UTR3        RUNX1
# 123631   UEB_14  chr21  36161902  36161903  CA   -         UTR3        RUNX1
# 123632   UEB_14  chr21  36164405  36164405   G   T         UTR3        RUNX1
# 123635   UEB_14  chr21  36193871  36193871   T   C         UTR3        RUNX1
#
# ...

# %%
df_final.to_csv('/home/fer/RevisionFrameshift_UTR.csv')
