# %%
library(QDNAseq)

# %%
All_QDNA <- function(path,bin,output) {
    bins <- getBinAnnotations(binSize=bin)
    readCounts <- binReadCounts(bins, path=path)
    readCountsFiltered <- applyFilters(readCounts, residual=TRUE, blacklist=TRUE)
    readCountsFiltered <- estimateCorrection(readCountsFiltered)
    copyNumbers <- correctBins(readCountsFiltered)
    copyNumbersNormalized <- normalizeBins(copyNumbers)
    copyNumbersSmooth <- smoothOutlierBins(copyNumbersNormalized)
    copyNumbersSegmented <- segmentBins(copyNumbersSmooth, transformFun="sqrt")
    #copyNumbersSegmented <- segmentBins(copyNumbersSmooth)
    copyNumbersSegmented <- normalizeSegmentedBins(copyNumbersSegmented)
    copyNumbersCalled <- callBins(copyNumbersSegmented)
    exportBins(copyNumbersCalled,file=output, format="vcf")
  return(copyNumbersCalled)
}

# %% [markdown]
# ### tarda 83 min (1:23 min)

# %%
UEB_205 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0205", 100, "UEB_0205_100kb_sqrt.vcf")
UEB_208 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0208", 100, "UEB_0208_100kb_sqrt.vcf")
UEB_209 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0209", 100, "UEB_0209_100kb_sqrt.vcf")
UEB_210 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0210", 100, "UEB_0210_100kb_sqrt.vcf")
UEB_211 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0211", 100, "UEB_0211_100kb_sqrt.vcf")
UEB_213 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0213", 100, "UEB_0213_100kb_sqrt.vcf")
UEB_214 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0214", 100, "UEB_0214_100kb_sqrt.vcf")
UEB_215 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0215", 100, "UEB_0215_100kb_sqrt.vcf")
UEB_216 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0216", 100, "UEB_0216_100kb_sqrt.vcf")
UEB_217 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0217", 100, "UEB_0217_100kb_sqrt.vcf")
UEB_218 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0218", 100, "UEB_0218_100kb_sqrt.vcf")
UEB_219 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0219", 100, "UEB_0219_100kb_sqrt.vcf")
UEB_220 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0220", 100, "UEB_0220_100kb_sqrt.vcf")
UEB_221 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0221", 100, "UEB_0221_100kb_sqrt.vcf")
UEB_222 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0222", 100, "UEB_0222_100kb_sqrt.vcf")
UEB_223 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0223", 100, "UEB_0223_100kb_sqrt.vcf")
UEB_224 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0224", 100, "UEB_0224_100kb_sqrt.vcf")
UEB_226 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0226", 100, "UEB_0226_100kb_sqrt.vcf")
UEB_227 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0227", 100, "UEB_0227_100kb_sqrt.vcf")
UEB_228 =All_QDNA("/home/fer/Documents/cfDNA/data/UEB_0228", 100, "UEB_0228_100kb_sqrt.vcf")
# Out:
# Loaded bin annotations for genome ‘hg19’, bin size 100 kbp, and experiment type ‘SR50’ from annotation package QDNAseq.hg19 v1.25.0
#
#     UEB_0205.recal.reads (1 of 1):
# extracting reads ...
#  binning ...
#
#
# 30,970	total bins
# 28,823	of which in selected chromosomes
# 27,006	of which with reference sequence
# 24,579	final bins
#
# Calculating correction for GC content and mappability
#
#     Calculating fit for sample UEB_0205.recal.reads (1 of 1) ...
#
# Done.
#
# Applying median normalization ...
#
#
# Smoothing outliers ...
#
#
# Performing segmentation:
#
#     Segmenting: UEB_0205.recal.reads (1 of 1) ...
#
# EM algorithm started ...
# [1] "Total number of segments present in the data: 30"
# [1] "Number of segments used for fitting the model: 27"
# Warning message in allprior/tot:
# “Recycling array of length 1 in vector-array arithmetic is deprecated.
#   Use c() or as.vector() instead.
# ”
# Warning message in allprior/tot:
# ...

# %%
par(mfcol = c(5, 2))
options(repr.plot.width = 20, repr.plot.height = 20)
plot(UEB_205,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_208,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_209,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_210,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_211,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_213,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_214,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_215,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_216,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_217,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
# Out:
# Plotting sample UEB_0205.recal.reads (32,275,295 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0208.recal.reads (34,132,434 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0209.recal.reads (36,170,994 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0210.recal.reads (36,298,590 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0211.recal.reads (36,003,615 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0213.recal.reads (30,704,220 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0214.recal.reads (33,277,771 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0215.recal.reads (34,131,271 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0216.recal.reads (31,187,500 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0217.recal.reads (41,513,713 reads) (1 of 1) ...
# Plot with title “UEB_0217.recal.reads (41,513,713 reads)”

# %%
par(mfcol = c(5, 2))
options(repr.plot.width = 20, repr.plot.height = 20)
plot(UEB_218,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_219,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_220,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_221,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_222,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_223,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_224,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_226,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_227,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
plot(UEB_228,pointcol="#696969", segcol="green",pointcex=getOption("QDNAseq::pointcex", 0.5))
# Out:
# Plotting sample UEB_0218.recal.reads (44,154,002 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0219.recal.reads (34,162,607 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0220.recal.reads (39,427,117 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0221.recal.reads (41,197,931 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0222.recal.reads (35,134,959 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0223.recal.reads (36,184,318 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0224.recal.reads (40,743,895 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0226.recal.reads (34,314,679 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0227.recal.reads (29,489,513 reads) (1 of 1) ...
#
#
# Plotting sample UEB_0228.recal.reads (30,542,018 reads) (1 of 1) ...
# Plot with title “UEB_0228.recal.reads (30,542,018 reads)”
