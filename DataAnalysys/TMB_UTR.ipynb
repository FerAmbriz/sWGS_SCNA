# %%
import pandas as pd

# %%
df = pd.read_csv('/home/fer/Documents/cfDNA/Tumor/Colombia_Merge.wNULL.txt', sep = '\t')
df
# Out:
# /tmp/ipykernel_23182/1884020921.py:1: DtypeWarning: Columns (33,34,35,36,37,38,42,46,49,52,55,58,61,64,67,72,75,78,86,87,107,108,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/fer/Documents/cfDNA/Tumor/Colombia_Merge.wNULL.txt', sep = '\t')
#          Sample             Chr   Start     End Ref Alt Func.refGene  \
# 0        UEB_10            chr1  527018  527018   G   A   intergenic
# 1        UEB_10            chr1  527030  527030   C   T   intergenic
# 2        UEB_10            chr1  863641  863641   G   A     intronic
# 3        UEB_10            chr1  863644  863644   T   C     intronic
# 4        UEB_10            chr1  863689  863689   A   G     intronic
# ...         ...             ...     ...     ...  ..  ..          ...
# 2136064  UEB_86  chrUn_gl000226   14292   14292   G   C   intergenic
# 2136065  UEB_86  chrUn_gl000226   14300   14300   T   G   intergenic
# ...

# %%
df['ExonicFunc.refGene'].value_counts()
# Out:
# synonymous SNV                8367
# nonsynonymous SNV             8046
# nonframeshift deletion        2264
# nonframeshift insertion        677
# frameshift deletion            586
# stopgain                       416
# frameshift insertion           325
# unknown                        252
# nonframeshift substitution     214
# stoploss                        10
# startloss                        6
# Name: ExonicFunc.refGene, dtype: int64

# %%
df['Func.refGene'].value_counts()
# Out:
# intergenic               1091189
# intronic                  825814
# ncRNA_intronic            121299
# UTR3                       26161
# exonic                     21152
# downstream                 17105
# upstream                   16708
# ncRNA_exonic                9046
# UTR5                        6188
# upstream;downstream         1026
# splicing                     299
# ncRNA_exonic;splicing         34
# ncRNA_splicing                30
# exonic;splicing               11
# UTR5;UTR3                      7
# Name: Func.refGene, dtype: int64

# %%
df_UTR = df[(df['Gene.refGene']=='SMAD4') & ((df['Func.refGene']=='UTR3') | (df['Func.refGene']=='UTR5') | (df['Func.refGene']=='UTR5;UTR3'))]
df_UTR
# Out:
#          Sample    Chr     Start       End    Ref Alt Func.refGene  \
# 36261    UEB_10  chr18  48606336  48606336      T   -         UTR3
# 36262    UEB_10  chr18  48609103  48609103      T   -         UTR3
# 36263    UEB_10  chr18  48609832  48609832      T   -         UTR3
# 36264    UEB_10  chr18  48609968  48609968      A   G         UTR3
# 36265    UEB_10  chr18  48610371  48610372     CA   -         UTR3
# ...         ...    ...       ...       ...    ...  ..          ...
# 2077183   UEB_8  chr18  48610698  48610702  AAGAA   -         UTR3
# 2077184   UEB_8  chr18  48610831  48610831      A   C         UTR3
# 2129545  UEB_86  chr18  48609103  48609103      T   -         UTR3
# 2129546  UEB_86  chr18  48609832  48609832      T   -         UTR3
# 2129547  UEB_86  chr18  48610382  48610382      G   A         UTR3
#
#         Gene.refGene               GeneDetail.refGene ExonicFunc.refGene  ...  \
# 36261          SMAD4            NM_005359:c.*1499delT                NaN  ...
# ...

# %%
#df_UTR.to_csv('/home/fer/Review.csv')

# %%
df_UTR['Func.refGene'].value_counts()
# Out:
# UTR3    357
# UTR5      5
# Name: Func.refGene, dtype: int64

# %%
x = df_UTR[df_UTR['Sample']=='UEB_47']
print(x['ClinVar_SIG'].to_list())
x
# Out:
# [nan, nan, nan, nan, nan, nan, 'Uncertain significance|Uncertain significance|Uncertain significance', 'Uncertain significance|Uncertain significance|Uncertain significance']
#          Sample    Chr     Start       End Ref     Alt Func.refGene  \
# 1308994  UEB_47  chr18  48605008  48605008   T       -         UTR3
# 1308995  UEB_47  chr18  48606178  48606178   -       T         UTR3
# 1308996  UEB_47  chr18  48606336  48606337  TT       -         UTR3
# 1308997  UEB_47  chr18  48609103  48609103   T       -         UTR3
# 1308998  UEB_47  chr18  48609831  48609831   -       T         UTR3
# 1308999  UEB_47  chr18  48610380  48610380   -  CACACA         UTR3
# 1309000  UEB_47  chr18  48610382  48610382   G       A         UTR3
# 1309001  UEB_47  chr18  48610584  48610584   -       T         UTR3
#
#         Gene.refGene                GeneDetail.refGene ExonicFunc.refGene  \
# 1308994        SMAD4              NM_005359:c.*171delT                NaN
# ...

# %%
z = '0/1:243,19:0.070:262:122,6:121,13:114,129,11,8'
z.replace(',', )
# Out:
# '0/1:243,19:0.070:262:122,6:121,13:114,129,11,8'

# %%
z = df['Otherinfo.11'][1].split(':')
z = z[0:7]
z
# Out:
# ['GT', 'AD', 'AF', 'DP', 'F1R2', 'F2R1', 'PGT']

# %%
x[z] = x['Otherinfo.12'].str.split(":", expand = True)
# Out:
# /tmp/ipykernel_23182/572369791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[z] = x['Otherinfo.12'].str.split(":", expand = True)
# /tmp/ipykernel_23182/572369791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[z] = x['Otherinfo.12'].str.split(":", expand = True)
# /tmp/ipykernel_23182/572369791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x
# Out:
#          Sample    Chr     Start       End Ref     Alt Func.refGene  \
# 1308994  UEB_47  chr18  48605008  48605008   T       -         UTR3
# 1308995  UEB_47  chr18  48606178  48606178   -       T         UTR3
# 1308996  UEB_47  chr18  48606336  48606337  TT       -         UTR3
# 1308997  UEB_47  chr18  48609103  48609103   T       -         UTR3
# 1308998  UEB_47  chr18  48609831  48609831   -       T         UTR3
# 1308999  UEB_47  chr18  48610380  48610380   -  CACACA         UTR3
# 1309000  UEB_47  chr18  48610382  48610382   G       A         UTR3
# 1309001  UEB_47  chr18  48610584  48610584   -       T         UTR3
#
#         Gene.refGene                GeneDetail.refGene ExonicFunc.refGene  \
# 1308994        SMAD4              NM_005359:c.*171delT                NaN
# 1308995        SMAD4       NM_005359:c.*1341_*1342insT                NaN
# 1308996        SMAD4      NM_005359:c.*1499_*1500delTT                NaN
# ...

# %%
x = df_UTR[df_UTR['Sample']=='UEB_47']
print(x['ClinVar_SIG'].to_list())
x
# Out:
# [nan, nan, nan, nan, nan, nan, 'Uncertain significance|Uncertain significance|Uncertain significance', 'Uncertain significance|Uncertain significance|Uncertain significance']
#          Sample    Chr     Start       End Ref     Alt Func.refGene  \
# 1308994  UEB_47  chr18  48605008  48605008   T       -         UTR3
# 1308995  UEB_47  chr18  48606178  48606178   -       T         UTR3
# 1308996  UEB_47  chr18  48606336  48606337  TT       -         UTR3
# 1308997  UEB_47  chr18  48609103  48609103   T       -         UTR3
# 1308998  UEB_47  chr18  48609831  48609831   -       T         UTR3
# 1308999  UEB_47  chr18  48610380  48610380   -  CACACA         UTR3
# 1309000  UEB_47  chr18  48610382  48610382   G       A         UTR3
# 1309001  UEB_47  chr18  48610584  48610584   -       T         UTR3
#
#         Gene.refGene                GeneDetail.refGene ExonicFunc.refGene  \
# 1308994        SMAD4              NM_005359:c.*171delT                NaN
# ...

# %%
x = df_UTR[df_UTR['Sample']=='UEB_44']
print(x['ClinVar_SIG'].to_list())
x
# Out:
# [nan, nan, 'Uncertain significance|Uncertain significance|Uncertain significance', nan, nan, nan, nan, 'Benign|Benign|Benign', 'Benign|Benign|Benign']
#          Sample    Chr     Start       End               Ref Alt Func.refGene  \
# 1212129  UEB_44  chr18  48606336  48606336                 T   -         UTR3
# 1212130  UEB_44  chr18  48609103  48609103                 T   -         UTR3
# 1212131  UEB_44  chr18  48609819  48609819                 -   T         UTR3
# 1212132  UEB_44  chr18  48609832  48609832                 T   -         UTR3
# 1212133  UEB_44  chr18  48610371  48610372                CA   -         UTR3
# 1212134  UEB_44  chr18  48610375  48610386      CGCGCGCGCACA   -         UTR3
# 1212135  UEB_44  chr18  48610377  48610392  CGCGCGCACACACACA   -         UTR3
# 1212136  UEB_44  chr18  48610698  48610702             AAGAA   -         UTR3
# 1212137  UEB_44  chr18  48610831  48610831                 A   C         UTR3
#
# ...

# %%
df_UTR = df[(df['Gene.refGene']=='STK11') & ((df['Func.refGene']=='UTR3') | (df['Func.refGene']=='UTR5') | (df['Func.refGene']=='UTR5;UTR3'))]
df_UTR
# Out:
#          Sample    Chr    Start      End        Ref Alt Func.refGene  \
# 37587    UEB_10  chr19  1206796  1206796          -   T         UTR5
# 37605    UEB_10  chr19  1228059  1228059          T   -         UTR3
# 37606    UEB_10  chr19  1228191  1228191          T   C         UTR3
# 37607    UEB_10  chr19  1228413  1228421  AAGCTTGGG   -         UTR3
# 120851   UEB_14  chr19  1228058  1228058          -   T         UTR3
# ...         ...    ...      ...      ...        ...  ..          ...
# 2032190  UEB_84  chr19  1228191  1228191          T   C         UTR3
# 2078671   UEB_8  chr19  1228059  1228059          T   -         UTR3
# 2078672   UEB_8  chr19  1228191  1228191          T   C         UTR3
# 2131714  UEB_86  chr19  1228059  1228059          T   -         UTR3
# 2131715  UEB_86  chr19  1228191  1228191          T   C         UTR3
#
#         Gene.refGene                 GeneDetail.refGene ExonicFunc.refGene  \
# ...

# %%
df_UTR[df_UTR['Sample'] == 'UEB_14']
#VUS Y BENIGNA
# Out:
#         Sample    Chr    Start      End Ref Alt Func.refGene Gene.refGene  \
# 120851  UEB_14  chr19  1228058  1228058   -   T         UTR3        STK11
# 120852  UEB_14  chr19  1228191  1228191   T   C         UTR3        STK11
#
#                GeneDetail.refGene ExonicFunc.refGene  ... Otherinfo.3  \
# 120851  NM_000455:c.*483_*484insT                NaN  ...       chr19
# 120852        NM_000455:c.*616T>C                NaN  ...       chr19
#
#         Otherinfo.4  Otherinfo.5  Otherinfo.6  Otherinfo.7  Otherinfo.8  \
# 120851      1228058          NaN            C           CT          NaN
# 120852      1228191          NaN            T            C          NaN
#
#                                     Otherinfo.9  \
# 120851  panel_of_normals;slippage;weak_evidence
# 120852                         panel_of_normals
#
#                                              Otherinfo.10  \
# 120851  AS_FilterStatus=weak_evidence;AS_SB_TABLE=44,5...
# ...

# %%
df_UTR[df_UTR['Sample'] == 'UEB_44']
# Conflicting, benigna y VUS
# Out:
#          Sample    Chr    Start      End Ref Alt Func.refGene Gene.refGene  \
# 1213730  UEB_44  chr19  1206796  1206796   -   T         UTR5        STK11
# 1213749  UEB_44  chr19  1228191  1228191   T   C         UTR3        STK11
# 1213750  UEB_44  chr19  1228243  1228243   C   A         UTR3        STK11
#
#                 GeneDetail.refGene ExonicFunc.refGene  ... Otherinfo.3  \
# 1213730  NM_000455:c.-117_-116insT                NaN  ...       chr19
# 1213749        NM_000455:c.*616T>C                NaN  ...       chr19
# 1213750        NM_000455:c.*668C>A                NaN  ...       chr19
#
#          Otherinfo.4  Otherinfo.5  Otherinfo.6  Otherinfo.7  Otherinfo.8  \
# 1213730      1206796          NaN            C           CT          NaN
# 1213749      1228191          NaN            T            C          NaN
# 1213750      1228243          NaN            C            A          NaN
#
#                                                Otherinfo.9  \
# ...

# %%
df_UTR[df_UTR['Sample'] == 'UEB_49']
# VUS, error, VUS, Benigna
# Out:
#          Sample    Chr    Start      End Ref Alt Func.refGene Gene.refGene  \
# 1361620  UEB_49  chr19  1206106  1206106   G   A         UTR5        STK11
# 1361621  UEB_49  chr19  1206797  1206797   T   -         UTR5        STK11
# 1361641  UEB_49  chr19  1228059  1228059   T   -         UTR3        STK11
# 1361642  UEB_49  chr19  1228191  1228191   T   C         UTR3        STK11
#
#            GeneDetail.refGene ExonicFunc.refGene  ... Otherinfo.3  \
# 1361620   NM_000455:c.-807G>A                NaN  ...       chr19
# 1361621  NM_000455:c.-116del-                NaN  ...       chr19
# 1361641  NM_000455:c.*484delT                NaN  ...       chr19
# 1361642   NM_000455:c.*616T>C                NaN  ...       chr19
#
#          Otherinfo.4  Otherinfo.5  Otherinfo.6  Otherinfo.7  Otherinfo.8  \
# 1361620      1206106          NaN            G            A          NaN
# 1361621      1206796          NaN           CT            C          NaN
# ...

# %% [markdown]
# # RUNX1

# %%
df_UTR = df[(df['Gene.refGene']=='RUNX1') & ((df['Func.refGene']=='UTR3') | (df['Func.refGene']=='UTR5') | (df['Func.refGene']=='UTR5;UTR3'))]
df_UTR
# Out:
#          Sample    Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 40498    UEB_10  chr21  36161902  36161903  CA   -         UTR3        RUNX1
# 40499    UEB_10  chr21  36162841  36162841   C   T         UTR3        RUNX1
# 40500    UEB_10  chr21  36164405  36164405   G   T         UTR3        RUNX1
# 40502    UEB_10  chr21  36193871  36193871   T   C         UTR3        RUNX1
# 40508    UEB_10  chr21  36259539  36259539   -   G         UTR5        RUNX1
# ...         ...    ...       ...       ...  ..  ..          ...          ...
# 2134917  UEB_86  chr21  36161882  36161883  CA   -         UTR3        RUNX1
# 2134918  UEB_86  chr21  36161902  36161903  CA   -         UTR3        RUNX1
# 2134919  UEB_86  chr21  36164405  36164405   G   T         UTR3        RUNX1
# 2134921  UEB_86  chr21  36193871  36193871   T   C         UTR3        RUNX1
# 2134926  UEB_86  chr21  36259539  36259539   -   G         UTR5        RUNX1
#
# ...

# %%
x = df_UTR[df_UTR['Sample']=='UEB_12']
print(x['ClinVar_SIG'].to_list())
x
# Out:
# [nan, 'Uncertain significance', 'Likely benign', 'Benign|Benign', nan, nan]
#        Sample    Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 84666  UEB_12  chr21  36161882  36161883  CA   -         UTR3        RUNX1
# 84667  UEB_12  chr21  36161901  36161901   -  CA         UTR3        RUNX1
# 84668  UEB_12  chr21  36162239  36162239   C   -         UTR3        RUNX1
# 84669  UEB_12  chr21  36164405  36164405   G   T         UTR3        RUNX1
# 84673  UEB_12  chr21  36193871  36193871   T   C         UTR3        RUNX1
# 84679  UEB_12  chr21  36259540  36259540   G   -         UTR5        RUNX1
#
#                                       GeneDetail.refGene ExonicFunc.refGene  \
# 84666  NM_001754:c.*2550_*2549delTG;NM_001001890:c.*2...                NaN
# 84667  NM_001754:c.*2530_*2531insTG;NM_001001890:c.*2...                NaN
# 84668     NM_001754:c.*2193delG;NM_001001890:c.*2193delG                NaN
# ...

# %%
z = list(x['GeneDetail.refGene'])
z
# Out:
# ['NM_001754:c.*2550_*2549delTG;NM_001001890:c.*2550_*2549delTG',
#  'NM_001754:c.*2530_*2531insTG;NM_001001890:c.*2530_*2531insTG',
#  'NM_001754:c.*2193delG;NM_001001890:c.*2193delG',
#  'NM_001754:c.*27C>A;NM_001001890:c.*27C>A',
#  'NM_001122607:c.*94A>G',
#  'NM_001001890:c.-131delC;NM_001122607:c.-131delC']

# %%
# Not found, Not found, Benigna, Benigna, Benigna, VUS

# %% [markdown]
# # UTR

# %%
df = pd.read_csv('/home/fer/Documents/cfDNA/Tumor/FiltradoFinal.txt', sep = '\t')
df
# Out:
#     Sample    Chr      Start        End   Ref  Alt Func.refGene Gene.refGene  \
# 0   UEB_10   chr3  178921553  178921553     T    A       exonic       PIK3CA
# 1   UEB_29   chr3  178952085  178952085     A    G       exonic       PIK3CA
# 2   UEB_30   chr3  178952090  178952090     G    C       exonic       PIK3CA
# 3   UEB_35   chrX  133549085  133549085     A    G       exonic         PHF6
# 4   UEB_39  chr13   32914515   32914515     -    G       exonic        BRCA2
# 5   UEB_43   chr3  178952085  178952085     A    G       exonic       PIK3CA
# 6   UEB_43   chrX   66765158   66765158     -  GCA       exonic           AR
# 7   UEB_47   chr3  178952085  178952085     A    G       exonic       PIK3CA
# 8   UEB_47  chr22   38379543   38379543     G    A       exonic        SOX10
# 9   UEB_51   chr3  178952072  178952072     A    G       exonic       PIK3CA
# 10  UEB_53   chr3  178952085  178952085     A    G       exonic       PIK3CA
# ...
